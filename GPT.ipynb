# %% [markdown]
# <a href="https://colab.research.google.com/github/philosophynote/machine_learning/blob/main/GPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://developer.mamezou-tech.com/blogs/2022/07/08/gpt-2-japanese/#%E3%83%95%E3%82%A1%E3%82%A4%E3%83%B3%E3%83%81%E3%83%A5%E3%83%BC%E3%83%8B%E3%83%B3%E3%82%B0-by-gpt2-medium

# %%
# !pip list

# %%
# !pip install transformers==4.21.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 68.7 MB/s
# ...
#      |████████████████████████████████| 182 kB 66.7 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/tanreinama/gpt2-japanese
# Out:
# fatal: destination path 'gpt2-japanese' already exists and is not an empty directory.

# %%
# !git clone https://github.com/rinnakk/japanese-pretrained-models
# Out:
# fatal: destination path 'japanese-pretrained-models' already exists and is not an empty directory.

# %%
cd japanese-pretrained-models/
# Out:
# /content/drive/MyDrive/Colab Notebooks/japanese-pretrained-models

# %%
# !pip install -r requirements.txt

# %%
import torch
from transformers import T5Tokenizer, AutoModelForCausalLM

# %%
# トークナイザーとモデルのロード
tokenizer = T5Tokenizer.from_pretrained("rinna/japanese-gpt-1b")
model = AutoModelForCausalLM.from_pretrained("rinna/japanese-gpt-1b")

# %%
if torch.cuda.is_available():
    model = model.to("cuda")

# %%
prompt = "AWS S3を色々いじっていて気がついたこと。バケット名の命名規約が他のAWSサービスと"

# %%
input_ids = tokenizer.encode(prompt, return_tensors="pt",add_special_tokens=False).to("cuda")

# %%
# 生成する文章の数
num = 3

# %%
with torch.no_grad():
    output = model.generate(
        input_ids,
        max_length=100, # 最長の文章長
        min_length=100, # 最短の文章長
        do_sample=True,
        top_k=500, # 上位{top_k}個の文章を保持
        top_p=0.95, # 上位{top_p}%の単語から選択する。例）上位95%の単語から選んでくる
        pad_token_id=tokenizer.pad_token_id,
        bos_token_id=tokenizer.bos_token_id,
        eos_token_id=tokenizer.eos_token_id,
        bad_word_ids=[[tokenizer.unk_token_id]],
        num_return_sequences=num # 生成する文章の数
    )

# %%
decoded = tokenizer.batch_decode(output,skip_special_tokens=True)
for i in range(num):
  print(decoded[i])
# Out:
# AWS S3を色々いじっていて気がついたこと。バケット名の命名規約が他のAWSサービスと違っていて混乱した。AWSのユーザー名とバケット名の対応表をどこかに用意して、仕様を統一して欲しくはある。 -- 2015-01-18 (日) 12:40:57 New! [ID: S.O.C.QJ.H] 2018-04-24 (火) 15:51:10 [ID: H244kIU_2]
# AWS S3を色々いじっていて気がついたこと。バケット名の命名規約が他のAWSサービスと異なっている。またGoogleが出しているWebサイト用ストレージ API「Google Cloud Platform」でのバケット名命名規約も同じことがいえる。どういうことか。AWS Lambdaを使う人はみんな知っていると思うけど一応紹介してみる。 Hello World. Microservices... Continue reading →... more... [続きを読む] about Cl
# AWS S3を色々いじっていて気がついたこと。バケット名の命名規約が他のAWSサービスと大きく異なっている。そう、GUIで設定できないのだ。 ↩︎ 2016年5月18日, このエントリは、AWS S3 Disclosure Managementのエントリーにつらつらと思いを綴ったものですが、当時の内容+若干の追加編集をしております ↩︎ 2016年6月23日, このエントリは、AWS S3 Disclos

# %%
pip install git+https://github.com/huggingface/transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-4scurvta
#   Running command git clone -q https://github.com/huggingface/transformers /tmp/pip-req-build-4scurvta
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for transformers: filename=transformers-4.25.0.dev0-py3-none-any.whl size=5734510 sha256=ae142893a01e54d61383a2f1e53fab5c5041ed9037a733492fa3b6a4dca17ab7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3apcvpff/wheels/35/2e/a7/d819e3310040329f0f47e57c9e3e7a7338aa5e74c49acfe522
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.21.3
#     Uninstalling transformers-4.21.3:
#       Successfully uninstalled transformers-4.21.3
# ...

# %%
# !git clone https://github.com/huggingface/transformers
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 116349, done.
# remote: Counting objects: 100% (458/458), done.
# remote: Compressing objects: 100% (313/313), done.
# remote: Total 116349 (delta 226), reused 248 (delta 114), pack-reused 115891
# Receiving objects: 100% (116349/116349), 110.01 MiB | 10.71 MiB/s, done.
# Resolving deltas: 100% (86557/86557), done.
# Checking out files: 100% (2720/2720), done.

# %%
pip install -r ./transformers/examples/pytorch/language-modeling/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 175 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 451 kB 45.0 MB/s
# ...
#      |████████████████████████████████| 72 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 212 kB 52.5 MB/s
# ...
#      |████████████████████████████████| 115 kB 75.9 MB/s
# ...
#      |████████████████████████████████| 127 kB 88.6 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# !python ./transformers/examples/pytorch/language-modeling/run_clm.py \
  --model_name_or_path=rinna/japanese-gpt2-medium \
  --train_file=hoge.txt \
  --do_train \
  --num_train_epochs=3 \
  --save_steps=10000 \
  --block_size 512 \
  --save_total_limit=3 \
  --per_device_train_batch_size=1 \
  --output_dir=output/ \
  --overwrite_output_dir \
  --use_fast_tokenizer=False
# Out:
# WARNING:__main__:Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# INFO:__main__:Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=False,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# ...

# %%
from transformers import T5Tokenizer, AutoModelForCausalLM
import torch

tokenizer = T5Tokenizer.from_pretrained("rinna/japanese-gpt2-medium")
tokenizer.do_lower_case = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# 学習したモデルを読み込む
model = AutoModelForCausalLM.from_pretrained("output/")
model.to(device)
model.eval()
# Out:
# ...
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(32000, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
# ...

# %%
# 初めの文章
prompt = "第四次の銀河鉄道なんか、どこまでで"
# 生成する文章の数
num = 1 

input_ids = tokenizer.encode(prompt, return_tensors="pt",add_special_tokens=False).to(device)
with torch.no_grad():
    output = model.generate(
        input_ids,
        max_length=100, # 最長の文章長
        min_length=100, # 最短の文章長
        do_sample=True,
        top_k=500, # 上位{top_k}個の文章を保持
        top_p=0.95, # 上位{top_p}%の単語から選択する。例）上位95%の単語から選んでくる
        pad_token_id=tokenizer.pad_token_id,
        bos_token_id=tokenizer.bos_token_id,
        eos_token_id=tokenizer.eos_token_id,
        bad_word_ids=[[tokenizer.unk_token_id]],
        num_return_sequences=num # 生成する文章の数
    )
decoded = tokenizer.batch_decode(output,skip_special_tokens=True)
for i in range(num):
  print(decoded[i])
# Out:
# 第四次の銀河鉄道なんか、どこまででもよくなってきた。 こんなところまでやってきたようです。今後どうなるのでしょうか。 それにしても、この世界の大都市はまだまだ空との距離が離れないようだ。 すでに92%は窓を開けても、そのうちどの部屋でも数分間の仮眠が取れるようになっている。 最近は6w4aで大体1時間半～3時間も寝られる。20年前のような、 この時間に動くことなく大丈夫
